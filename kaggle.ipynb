# %%
import pandas as pd 
df=pd.read_csv("city_temperature.csv")
# Out:
# C:\Users\Aspire\AppData\Local\Temp\ipykernel_10748\719393325.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("city_temperature.csv")

# %%
df
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(x=df["AvgTemperature"]);

# %%
sns.boxplot(x="Year",y="AvgTemperature",data=df);

# %%
sns.catplot(y="AvgTemperature",kind="violin",data=df);

# %%
sns.scatterplot(x="AvgTemperature",y="Year",data=df);

# %%
sns.lmplot(x="AvgTemperature",y="Year",data=df.head(5000));

# %%
sns.lineplot(x="AvgTemperature",y="Year",data=df.head(50));

# %%
close=df["AvgTemperature"].head(5000)
close.plot();
